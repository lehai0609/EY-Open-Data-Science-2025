# %%
import pandas as pd
df = pd.read_csv("../input/person_puf_21.csv")
df.head()
# Out:
#     CONTROL  LNO  RELATION_P  AGE_REC_P  GENDER_P  MARITALSTAT_P  \
# 0  12100003    1           0         64         2              5
# 1  12100005    1           0         88         2              4
# 2  12100008    1           0         48         1              5
# 3  12100008    2           9         20         1             -2
# 4  12100008    3          11         38         2             -2
#
#    SPOUSE_RES_P  SPOUSE_LOC_P  SPOUSE_P  LNSPOUSE_P  ...        PW71  \
# 0            -2            -2        -2          -2  ...  278.606133
# 1            -2            -2        -2          -2  ...   78.208915
# 2            -2            -2        -2          -2  ...  431.305905
# 3            -2            -2         3          -2  ...  376.707949
# 4            -2            -2         3          -2  ...  275.381410
#
#          PW72        PW73        PW74        PW75        PW76        PW77  \
# 0   45.760787  154.534690  263.432217  158.256946   46.126499  155.823325
# ...
